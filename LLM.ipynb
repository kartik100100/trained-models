# %%
import numpy as np 
import pandas as pd 
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv(r"C:\Users\karti\OneDrive\Desktop\LLM dataset\train.csv")
df.head()
test = pd.read_csv(r"C:\Users\karti\OneDrive\Desktop\LLM dataset\test.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57477 entries, 0 to 57476
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              57477 non-null  int64
#  1   model_a         57477 non-null  object
#  2   model_b         57477 non-null  object
#  3   prompt          57477 non-null  object
#  4   response_a      57477 non-null  object
#  5   response_b      57477 non-null  object
#  6   winner_model_a  57477 non-null  int64
#  7   winner_model_b  57477 non-null  int64
#  8   winner_tie      57477 non-null  int64
# dtypes: int64(4), object(5)
# memory usage: 3.9+ MB

# %%
df.columns
col = ['id','model_a', 'model_b', 'prompt', 'response_a', 'response_b',
       'winner_model_a', 'winner_model_b', 'winner_tie']

tar = ['winner_model_a', 'winner_model_b', 'winner_tie']

var = ['id','model_a', 'model_b', 'prompt', 'response_a', 'response_b']

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['model_a'] = le.fit_transform(df['model_a'])
df['model_b'] = le.fit_transform(df['model_b'])
df['prompt'] = le.fit_transform(df['prompt'])
df['response_a'] = le.fit_transform(df['response_a'])
df['response_b'] = le.fit_transform(df['response_b'])

# %%
df.head()
# Out:
#        id  model_a  model_b  prompt  response_a  response_b  winner_model_a  \
# 0   30192       24       23   17442       42794        6620               1
# 1   53567       27       23   29028        3571        3559               0
# 2   65089       19       35   40346       12318       12369               0
# 3   96401       29       33   10340       10217       50966               1
# 4  198779       27       18   28804       39624       39698               0
#
#    winner_model_b  winner_tie
# 0               0           0
# 1               1           0
# 2               0           1
# 3               0           0
# 4               1           0

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
df['id'] = scaler.fit_transform(df[['id']])
df['model_a'] = scaler.fit_transform(df[['model_a']])
df['model_b'] = scaler.fit_transform(df[['model_b']])
df['prompt'] = scaler.fit_transform(df[['prompt']])
df['response_a'] = scaler.fit_transform(df[['response_a']])
df['response_b'] = scaler.fit_transform(df[['response_b']])

# %%
df['winner_model_a'] = scaler.fit_transform(df[['winner_model_a']])
df['winner_model_b'] = scaler.fit_transform(df[['winner_model_b']])
df['winner_tie'] = scaler.fit_transform(df[['winner_tie']])

# %%
x = df.drop(['winner_model_a', 'winner_model_b', 'winner_tie'], axis=1)
y = df['winner_model_a']
print(x)
print(y)
# Out:
#              id   model_a   model_b    prompt  response_a  response_b
# 0      0.000000  0.380952  0.365079  0.337154    0.756546    0.116945
# 1      0.000005  0.428571  0.365079  0.561112    0.063131    0.062871
# 2      0.000008  0.301587  0.555556  0.779889    0.217767    0.218503
# 3      0.000015  0.460317  0.523810  0.199872    0.180624    0.900332
# 4      0.000039  0.428571  0.285714  0.556782    0.700504    0.701279
# ...         ...       ...       ...       ...         ...         ...
# 57472  0.999932  0.365079  0.079365  0.021089    0.656059    0.310539
# 57473  0.999941  0.095238  0.460317  0.325247    0.308512    0.620248
# 57474  0.999945  0.079365  0.015873  0.851661    0.912808    0.467160
# 57475  0.999989  0.698413  0.873016  0.305685    0.150517    0.108942
# 57476  1.000000  0.253968  0.380952  0.902441    0.048617    0.420029
#
# [57477 rows x 6 columns]
# 0        1.0
# 1        0.0
# 2        0.0
# 3        1.0
# 4        0.0
#         ...
# 57472    1.0
# ...

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.1, random_state=42)

# %%
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor, GradientBoostingClassifier, GradientBoostingRegressor
from sklearn.neighbors import KNeighborsClassifier, KNeighborsRegressor
from sklearn.svm import SVC, SVR

# %%
from sklearn.preprocessing import FunctionTransformer
trf = FunctionTransformer()

# %%
x_train1 = trf.fit_transform(x_train)
x_test1 = trf.fit_transform(x_test)

# %%
model = GradientBoostingRegressor()
model.fit(x_train1,y_train)
# Out:
# GradientBoostingRegressor()

# %%
from sklearn.metrics import accuracy_score

# %%
pred = model.predict(x_test1)
accu = accuracy_score(y_test,pred)
print(accu)
# Out:
# 0.6000347947112039
